# %% [markdown]
# # Discover Insights  and generate text from Gutenberg Project

# %% [markdown]
# Project Gutenberg (PG) is a volunteer effort to digitize and archive cultural works, as well as to "encourage the creation and distribution of eBooks. It was founded in 1971 by American writer Michael S. Hart and is the oldest digital library. Most of the items in its collection are the full texts of books or individual stories in the public domain. All files can be accessed for free under an open format layout, available on almost any computer. As of 3 October 2015, Project Gutenberg had reached 50,000 items in its collection of free eBooks.

# %% [markdown]
# ## Import and Preprocess Text Data

# %%
import nltk
nltk.download('gutenberg')
from nltk.corpus import gutenberg as gb

files_names= gb.fileids()
from nltk.tokenize import word_tokenize , sent_tokenize
print(files_names)
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\Chrispdl\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %% [markdown]
# ## Preview the data
# Let's write a short program to display other information about each text, by looping over all the values of fileid corresponding to the gutenberg file identifiers listed earlier and then computing statistics for each text. For a compact output display, we will round each number to the nearest integer, using round().

# %%
from nltk.corpus import gutenberg as gb
for fileid in gb.fileids():
    num_chars = len(gb.raw(fileid))
    num_words = len(gb.words(fileid))
    num_sents = len(gb.sents(fileid))
    num_vocab = len(set(w.lower() for w in gb.words(fileid)))
    print(round(num_chars/num_words), round(num_words/num_sents), round(num_words/num_vocab), fileid)
# Out:
# 5 25 26 austen-emma.txt
# 5 26 17 austen-persuasion.txt
# 5 28 22 austen-sense.txt
# 4 34 79 bible-kjv.txt
# 5 19 5 blake-poems.txt
# 4 19 14 bryant-stories.txt
# 4 18 12 burgess-busterbrown.txt
# 4 20 13 carroll-alice.txt
# 5 20 12 chesterton-ball.txt
# 5 23 11 chesterton-brown.txt
# 5 19 11 chesterton-thursday.txt
# 4 21 25 edgeworth-parents.txt
# 5 26 15 melville-moby_dick.txt
# 5 52 11 milton-paradise.txt
# 4 12 9 shakespeare-caesar.txt
# 4 12 8 shakespeare-hamlet.txt
# 4 12 7 shakespeare-macbeth.txt
# 5 36 12 whitman-leaves.txt

# %% [markdown]
# ## Import necessary libraries

# %%
import nltk
import random 
from collections import Counter, defaultdict
from nltk.corpus import PlaintextCorpusReader
from nltk import bigrams
from nltk import trigrams
from nltk.util import ngrams 
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Chrispdl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Choose 10 books

# %%
# Get a list of texts by Chesterton , Austen , Shakespeare and the Bible
files_used = []                        # empty list to hold filenames
for file in files_names:                   # look at each filename in turn
    if 'chesterton' in file or 'austen' in file or 'shakespeare' in file or 'bible' in file:         # test if it's a Chesterton
        files_used.append(file)         # add file to the list
print(files_used)
print(len(files_used))
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt']
# 10

# %%
for j in files_used:
    #splitting the text to words and sentences
    sents= gb.sents(j) 
    words= gb.words(j)
    #Unigram Model 
    counts_word = Counter(words)
    #print(counts_word.most_common(n=5)) #prints the most common words
    for word in counts_word:
        counts_word[word] /= len(counts_word)

    #Bigram Model
    #Creating a dictionary containing the bigrams and the probability:
    bigram_model = defaultdict(lambda: defaultdict(lambda: 0))

    # Add 1 each time the two combinations of the 2 words exists
    for sentence in sents:
        for word1, word2 in bigrams(sentence, pad_right = True, pad_left = True):
            bigram_model[word1][word2] += 1


    # Iterating through the model and calculating the probability of the bigrams
    for word1 in bigram_model:

        total_count = float(sum(bigram_model[word1].values()))
        # If the total_count == 0  meansthe bigram does not exist, then it should skip it
        if total_count == 0:
            pass
        # Again if it does not exist assign the value 0 
        for word2 in bigram_model[word1]:
            if total_count == 0:
                bigram_model[word1][word2] = 0
            # If the brigram is not 0, then it calculates the probability
            else:
                bigram_model[word1][word2] /= total_count
            
        
    #print(str(dict(bigram_model)))
    print('Generating sentences from book',j,'using bigrams')
    #generating sentences using bigrams
    for i in range(10):
        text = [None]
        sentence_finished = False
        count = 0
        while not sentence_finished:

            r = random.random()
            accumulator = .0

            if len(text) == 1:
                var = bigram_model[None]
            else:
                tup_text = tuple(text)

                var = bigram_model[tup_text[-1]]


            for word in var.keys():

                accumulator += var[word]

                if accumulator >= r:

                    text.append(word)
                    break
                else:

                    pass
            if text[-1:] == ['.']:
                sentence_finished = True

        print ('Generated sentence', i  ,'\n', ' '.join([t for t in text if t]))

    #trigram 
    # Creating a dictionary containing the two words and then the words that comes after as well as the probability: 
    trigram_model = defaultdict(lambda: defaultdict(lambda: 0))

    # Adding  1 each time the trigram exists
    for sentence in sents:
        for word1, word2, word3 in trigrams(sentence, pad_right = True, pad_left = True):
            trigram_model[(word1, word2)][word3] += 1

    # Iterating through the model and calculating the probability of the trigrams
    for word1_word2 in trigram_model:
         # If the total_count == 0 means the trigram does not exist, then it should skip it
        total_count = float(sum(trigram_model[word1_word2].values()))
        if total_count == 0:
            pass
        # Again if it does not exist assign the value 0 
        for word3 in trigram_model[word1_word2]:
            if total_count == 0:
                trigram_model[word1_word2][word3] = 0
            # If the brigram is not 0, then it calculates the probability
            else:
                trigram_model[word1_word2][word3] /= total_count



    print('Generating sentences from book',j,'using trigrams')
    for i in range(10):
        text = [None, None]
        sentence_finished = False

        while not sentence_finished:
            r = random.random()
            accumulator = .0

            for word in trigram_model[tuple(text[-2:])].keys():
                accumulator += trigram_model[tuple(text[-2:])][word]

                if accumulator >= r:

                    text.append(word)
                    break
                else:
                    pass
            if text[-1:] == ['.']:
                sentence_finished = True

        print('Generated sentence',i  ,'\n', ' '.join([t for t in text if t]))
# Out:
# Generating sentences from book austen-emma.txt using bigrams
# Generated sentence 0
#  But have always do not like therefore , at seventeen .
# Generated sentence 1
#  The evil , for her cheeks in a large a heavy work to Donwell !" " But after dinner , at Enscombe must consider whether in character , and it was most deplorable mistake not prejudiced ; and yet it , to get walnuts , which accounted for her visitors perhaps .-- Yes ; it had at all there was led her .
# Generated sentence 2
#  But hush , so odd !-- Can you at somebody had reached Mrs .
# Generated sentence 3
#  at a very glad to town , a few turns out again , without great deal I find her it as I am I are always good deal under my intentions were not unpretty ; but the sick of mutton for a chair near so very well as the convenience of his sanction to myself .
# Generated sentence 4
#  " Does Mrs .
# Generated sentence 5
#  He had ever refuse him to do envy him to Box Hill though she found more moderate -- it be so much more safely entered the young lady , was to interfere .
# Generated sentence 6
#  That nature ; if I dare say always so immediately talk about the time , Emma even July , smiling -- and some hours without any lead the consequence herself made such society , I made for going on , by her attention to leave it was to convince you any body invites their own horses to bring you do less , now he sat smiling and made ; and it from those for this subject .
# Generated sentence 7
#  Mr .
# Generated sentence 8
#  " Dear Jane Fairfax should be assured that I shall soon have come over .
# Generated sentence 9
#  There is totally different at Hartfield , and care for I conclude before him and with fewer resources , among the morning of a very proper to Jane answered most weakly ; and consistent degree of unreserve , you .
# Generating sentences from book austen-emma.txt using trigrams
# Generated sentence 0
#  Dear me , and it makes one more , he very far , very much in the power of eating and drinking were often the cure of all the rest of her in consternation , and should be extremely sorry and ashamed we were not in love with him as to my brother imagined ? Emma spared no exertions to maintain this happier flow of happy exemption from Mr .
# Generated sentence 1
#  At this moment ; never properly aired , or when Mrs .
# Generated sentence 2
#  Had he said , that she could not satisfy Mrs .
# Generated sentence 3
#  It was a general cry - out past was sunk in the best blessings of existence ; and there is but one .
# Generated sentence 4
#  " I suppose , and when you grow old ?" _She_ certainly had not escaped her .
# Generated sentence 5
#  I can go no where , when I first arrived at Randalls one day ( and there , in a graver tone , The next morning to night .-- There he was therefore later than he really loves Jane Fairfax .
# Generated sentence 6
#  She was not really necessary to reinstate her in a total want of attention to the kind ;-- and for Harriet , what would Mr .
# Generated sentence 7
#  I cannot say how soon I suppose ?" " I shall yet dread making the match .
# Generated sentence 8
#  Jane , Miss Woodhouse ," said Emma playfully .
# Generated sentence 9
#  He fancied bathing might be a parlour - boarder .
# Generating sentences from book austen-persuasion.txt using bigrams
# Generated sentence 0
#  no feelings of the room ) " Charles ' s age , I hate the past -- And not you .
# Generated sentence 1
#  " very high part of her , and " on shore ; sure , was open to reflect .
# Generated sentence 2
#  A little advance , and Mary ' s death that no sooner than an overthrow of economy , and looked and Louisa Musgrove had been worse than if not ;' and to talk about me ." But everything .
# Generated sentence 3
#  It was more than their value of her arrival of keeping up her in itself strong feelings she had appeared completely astonished .
# Generated sentence 4
#  Sir Walter , for them , sinking heart to walk must really a mere Mr Elliot ' s room , assured him immoveable impression at the better than one ' s being kept theirs .
# Generated sentence 5
#  How Charles Hayter , by the real circumstances of visiting in sensibility and was in turning her friend , but she could be together .
# Generated sentence 6
#  If Elizabeth was come back , said it takes a suspension of her the sisters , most unfortunate , that your nice children , however , had been at Lyme , when he would be a second W .
# Generated sentence 7
#  His bright eye was now you have been music she had been always the moment , perhaps --" " Indeed , though nearer to complain , a knowledge of writing about Winthrop , as she was the precious .
# Generated sentence 8
#  The something should you at Uppercross as to ask Captain Wentworth ," replied he replied Mrs Musgrove was but as they could at least missed ." " Certainly : but at the body or spirits not be conjectured him was stretched before she could not listen no need not quite as did not such an idea ! If Elizabeth , to vary , as he was precisely what I always sure she smiled more and to accept him ." It was wishing to be connected with sympathetic touch in higher spirits was to Anne sighed Anne ' s nature of habit was it was a whole had not be carried away ), " I was to suffer the family .
# Generated sentence 9
#  She goes into .
# Generating sentences from book austen-persuasion.txt using trigrams
# Generated sentence 0
#  cried Sir Basil , ` or perhaps sixty - two so respectably removed from the windows and doors against the wall for his sake ; and hoped , ere long , uneventful residence in one , and the others , if you do not think it a great deal too much to leave Lyme , to stay for .
# Generated sentence 1
#  she would never do .
# Generated sentence 2
#  They went to him ? I can produce it ." It had been for the opportunity .
# Generated sentence 3
#  " The Admiralty ," he must have been quite at ease about my dear Miss Louisa , and fix at Lyme ." Anne had no distrust of herself , but declined it all to go and help nurse dear Miss Elliot ' s , and ease and animation of a man .
# Generated sentence 4
#  Shall I mention to the sands , make her infinitely superior to her soon afterwards , or hers , may be conceived .
# Generated sentence 5
#  She is not a woman of family attachment and family honour , than any other woman I want you to go with the happiness of being conveyed home in consequence .
# Generated sentence 6
#  Lord ! After a short one .
# Generated sentence 7
#  Her father and mother , and Sir Walter ' s account .
# Generated sentence 8
#  It was with her companion , and of finding such words , for the eldest son , he was already quite alive again .
# Generated sentence 9
#  I should be struck out by one or two from Lyme , without saying a word , he spoke , there was no end of the room .
# Generating sentences from book austen-sense.txt using bigrams
# Generated sentence 0
#  She found out of both wished that he said she had I shall hear ; and went out ,-- -- a living !-- But Marianne and shook her sisters ! Mr .
# Generated sentence 1
#  " I could , or ' But when they are both mother must be coming of Mrs .
# Generated sentence 2
#  Relate only suffering for then talked of returning to see her sake , who was her .
# Generated sentence 3
#  How cold or at least astonished at least I left to her own judgment I should she agreed , and affectionate than inclination to say to her mother .
# Generated sentence 4
#  But yet to look of hills did you know where there , and fortunately she received intelligence of January .
# Generated sentence 5
#  Mrs .
# Generated sentence 6
#  Three thousand a curiosity must have been able to go and Lucy in accepting it is not mean Mrs .
# Generated sentence 7
#  Good God ! Marianne , for , was not know , that they drew her soon or I can so much about it all in a gentle and her voice of danger is this kind of what a year .
# Generated sentence 8
#  " it reach his mother will , half frantic ." NOW , was far less to give such a faith in hopes .
# Generated sentence 9
#  Mr .
# Generating sentences from book austen-sense.txt using trigrams
# Generated sentence 0
#  In the evening ; for to be to Mrs .
# Generated sentence 1
#  The people !" " Don ' s ship cut them .
# Generated sentence 8
#  might never understand that invisibility and Homeric truce the only saved himself the tropics .
# Generated sentence 9
#  Evan , when they were entering a monster than fleeing from the singular conclusion , falling on the garden wears good - red - coated doctors in her ." said , 2002 as if I don ' t be progressive .
# Generating sentences from book chesterton-ball.txt using trigrams
# Generated sentence 0
#  " I can ' t a man going through an ancient formality .
# Generated sentence 1
#  THE OTHER PHILOSOPHER The cursed pack of rat - catching chemists all say that you know what the deuce ! There was no bigger than they might easily have made in Fleet Street , seeking some half - tipsy yokel who was in the very thing you point to as the sun on every conceivable kind of explanation , " more important than anything else to say ----" That is the voice of thunder , " then I was born and bred and taught in a nightmare .
# Generated sentence 2
#  It is folly to talk to you , because today the whole truth .
# Generated sentence 3
#  " I know it cannot be named .
# Generated sentence 4
#  After a very small public house , and her good name and stock a Highlander of the room , but his eyes were very lenient with us ," he said with a sort of strange pity that this paling was an army of goblins .
# Generated sentence 5
#  The rest was almost absolutely white , except seeing him .
# Generated sentence 6
#  The thing got up half stupidly , with one long and heavy cane .
# Generated sentence 7
#  Stiffening in himself the masculine but mirthless courage of the victorious sun was beating , burnishing it all like gold , those unique and indescribable things of that headlong machine .
# Generated sentence 8
#  " But this man ' s reality .
# Generated sentence 9
#  Year after year went by .
# Generating sentences from book chesterton-brown.txt using bigrams
# Generated sentence 0
#  " I may go to say so that very decisively declined to take a pike - browed cavern of the smiling .
# Generated sentence 1
#  Looking at as they ' s eyes .
# Generated sentence 2
#  " Stranger than -- and very broad sombrero fallen dead colours was not tremendously agitated eyes to vague ideas .
# Generated sentence 3
#  Cray , was vain to hit anything about the Major Putnam , John Boulnois says he left boot ; " Don ' t be any hole or ` aren ' s very well as the dog and sparkling rapier and his arms flung himself and the Duke ; and crowned with a man being the Natural Philosophy Quarterly a hereditary disproportion in the buck nigger than any topic .
# Generated sentence 4
#  And he swung it from the open , unbrushed head ." There was said Mr Todd is the tables outside the difference between the passage after Seymour had a second Spaniard , laying down it .
# Generated sentence 5
#  Footmen from the romances about so .
# Generated sentence 6
#  You must have confirmed the staring Usher found the figure ran out of trust my attention , at his head repeatedly .
# Generated sentence 7
#  Father Brown sat down by G .
# Generated sentence 8
#  There are probably never go : in this moment one selected from most precious truth that had gone for Holy Church I did you must help me ." " but distinct .
# Generated sentence 9
#  But the swords ." He was trying to the smell of newspaper .
# Generating sentences from book chesterton-brown.txt using trigrams
# Generated sentence 0
#  he muttered ; " but there is no curse on him -- a muffled figure bending forward , evidently peering out into the steering - seat of a watering - place , who was stepping with considerable coolness into the street ." We can direct our moral wills ; but deliberation could not ` X - ray ' the coin from Hawker , because they must be the chance blunders of a mysterious chieftain with an air of some of your critique of the road along the sea ?" But such things before -- were at once luminous and discoloured by the pursuers ; but when the brute has huge humped shoulders and hog ' s private room of the Pendragons in the time when he spoke , the man turned to look after her ? The convict settlement at Sequah is thirty miles from the room was standing with his mouth to speak and his hair ( which was that the house ; and I thought I had , however high they went , the hues of a banquet over - powering projects .
# Generated sentence 1
#  " It makes one feel ," said Ezza , if you showed an Ancient Briton a revolver , I made a will leaving the mocking mouth uncovered .
# Generated sentence 2
#  But I think I put on me ; I can ' t be only too pleased to think that what gave me my first faint suspicion about the gossip and the judge , he seemed to consist in a black butterfly tie and lugubrious visage down to the little priest came scrambling out of this Australian brother who ratted ? I no longer profess an observance of the story of the detective , " I ' ve saved him from London .
# Generated sentence 3
#  " I ' m not quite so ignorant , you know who ' s name is Todd ," said the ugliest part of the man shortly ; " I mean , that made him look like a nut ; he spent nothing on himself ; the afternoon was closing in on John ' s superstition with a wind ; and another had his attention drawn by larrikins to a credulous public if it had been occupied by a doctor .
# Generated sentence 4
#  I was engaged to was coming in first drawer to the musical service .
# Generated sentence 5
#  " What does it matter what it was not in the eighteenth century ; the smell of something that put the end of the sword , and turned his head ; so that they had then been joined for a pleasure boat so small as theirs ; but I was lunching in that ancient park .
# Generated sentence 6
#  I was saying to Flambeau .
# Generated sentence 7
#  But the little priest watched , like a terrace overlooking the sunset , or perhaps more , in every other suspicion breaks down on them ," said the philosopher slowly , and was close to the Court named Hedwig had any previous knowledge of the great Ludwig in the trees and blew up into sub - headings , which I could not say the words have to bear alone , if anything , than there was no longer unconventional , but with clenched hands , and there with a good deal farther ; and since then Exmoor has been washed down to watch it .
# Generated sentence 8
#  He could not have meant that while they saw in the right , then ? If that is also quite true , as he spoke again in his own gate , with some irrelevance , " there must be of a way that was probably vigorous , and then in charcoal .
# Generated sentence 9
#  For the first public rank .
# Generating sentences from book chesterton-thursday.txt using bigrams
# Generated sentence 0
#  " How would always to catch him .
# Generated sentence 1
#  asked the sky , and everything , which was no way , and pleasure of a fight with a dreadful and that under the Council , tenth or three cabs , clamorous voices , a rush , and drink at a woman ever before the beauties of trees and stared over the Council .
# Generated sentence 2
#  he flicked a friend ' s a farcical ingenuity , their atrocities by which we are , and had two holes .
# Generated sentence 3
#  cried .
# Generated sentence 4
#  cried out to split once tickled and asthmatic breathing .
# Generated sentence 5
#  Would you as Syme struck stiff face transfigured to be a dog , of detail , and smiling embarrassment .
# Generated sentence 6
#  Most of Saffron Park .
# Generated sentence 7
#  But in that whenever the window and ended and eggs upon their farcical ingenuity , but I concede the large , secondly tears , with violence , Syme had abolished all his collar there as Gogol without right ," replied the perfect a dog -- A second -- But there sprang erect , but hear Comrade Syme was free London , by all nuzzinks .
# Generated sentence 8
#  Dr .
# Generated sentence 9
#  But to bed !" Syme indignantly .
# Generating sentences from book chesterton-thursday.txt using trigrams
# Generated sentence 0
#  asked Syme quickly .
# Generated sentence 1
#  The moment he minded it no more than once had in his left hand of it , while wooded on both sides of the country .
# Generated sentence 2
#  I was a habit of the banisters .
# Generated sentence 3
#  The more his own very strong , and you may safely read .
# Generated sentence 4
#  If we had abolished all conventions ." The Secretary choked for a sublime effort before speaking .
# Generated sentence 5
#  " They have unslung their carbines ," cried Bull dancing with excitement .
# Generated sentence 6
#  That ' s it ," said Gregory , in the sincerity of his black Assyrian eyebrows in surprise , but in softer materials ; his hands -- The enormous man was subtly and delicately false .
# Generated sentence 7
#  " I ' m in the meeting ?" At the risk ?" " What does it matter who is , as sharp as a cow , and then the queer bird which had fixed itself on his galley and his eyes might be public , the dear old boy has turned out on an early breakfast next morning while the skies will fall in the next station were unaccountably Baker Street or to Bagdad .
# Generated sentence 8
#  asked Syme , beaming over the edge like black treacle .
# Generated sentence 9
#  Let ' s caprice they had properly realised the breathless process .
# Generating sentences from book shakespeare-caesar.txt using bigrams
# Generated sentence 0
#  I am the while , when he smiles in Stand not doubted .
# Generated sentence 1
#  Enter Brutus , Who is Cassius from the Heauens : Fast asleepe ? Cassi .
# Generated sentence 2
#  There was Caesars deaths , And some one another ? Nor to Caesars death : his bloody fingers , Nor to meet , Who doth say , We are but onely in that poore men Begin it Away then his Night is a wish , be satisfied As a Tyrant Cassi .
# Generated sentence 3
#  I should be in his Comment Alarum .
# Generated sentence 4
#  Ser .
# Generated sentence 5
#  Fla .
# Generated sentence 6
#  We both deceiu ' de by tokens send a Fellow ; So sayes , Or else ? ' d thee well as these , for Romans Cassi .
# Generated sentence 7
#  1 .
# Generated sentence 8
#  Bru .
# Generated sentence 9
#  Why so : And that would be heere of March ? Stand Cassi .
# Generating sentences from book shakespeare-caesar.txt using trigrams
# Generated sentence 0
#  I should know no Secrets That appertaine to you euery one .
# Generated sentence 1
#  Enter Cassius and Titinius mourning it No Cassius : The Gods do this in Art as you are come Enter Souldiers , and Romans yet ere night , and Flauius .
# Generated sentence 2
#  There is so much vpon your health , He will be heere againe , hee put it by with the Gowne .
# Generated sentence 3
#  Antony , our great Ancestor , Did loose his Lustre : I trouble thee too much vpon my Boy , That were you , But with an hundred spouts Did run pure blood : and as I was , You are contented to be thus waited for .
# Generated sentence 4
#  I am sure it is Caska , we will grace his Speech Tending to Caesars Funerall .
# Generated sentence 5
#  Clocke strikes .
# Generated sentence 6
#  Cai .
# Generated sentence 7
#  Sennet Luc .
# Generated sentence 8
#  What is ' t please you Brut .
# Generated sentence 9
#  3 .
# Generating sentences from book shakespeare-hamlet.txt using bigrams
# Generated sentence 0
#  Guil .
# Generated sentence 1
#  I am guiltlesse of Ioue himselfe in Obedience , though it selfe scapes not stopp a making so the Ayre promise , As meditation , more Then is not , That shall obey my Mother , I saw them ranke .
# Generated sentence 2
#  Hee may there is very likely , That they are oft before the Sunne , It was seated on , has laine in your death .
# Generated sentence 3
#  You must put the dreadfull Thunder .
# Generated sentence 4
#  Kin .
# Generated sentence 5
#  Polon .
# Generated sentence 6
#  This to our selfe Exit Hamlet .
# Generated sentence 7
#  My Lord ? Most throughly for England .
# Generated sentence 8
#  Exeunt .
# Generated sentence 9
#  Sir .
# Generating sentences from book shakespeare-hamlet.txt using trigrams
# Generated sentence 0
#  Polon .
# Generated sentence 1
#  Ham .
# Generated sentence 2
#  Come away .
# Generated sentence 3
#  Sir , Enquire me first what Danskers are in Paris ; And thy Commandment all alone shall liue Within the Center Guild .
# Generated sentence 4
#  Ser .
# Generated sentence 5
#  I dare Damnation : to me I know not what we are Pictures , or the Poesie of a sorrow , I could tell you why ; so fare ye well : y ' are a good end ; For by the image of my Watch , bid them make hast .
# Generated sentence 6
#  Vnhand me Gentlemen : By Heauen I charge you ; And how , and sent into England ? Is it not that I hope will teach you to imagine - Enter a King and Queene , that it were better my Mother , for the Players .
# Generated sentence 7
#  King .
# Generated sentence 8
#  Laer .
# Generated sentence 9
#  Mar .
# Generating sentences from book shakespeare-macbeth.txt using bigrams
# Generated sentence 0
#  1 Appar .
# Generated sentence 1
#  O , Verity , to kill ' s more , and Seyward , To say ( as it lies like the very Ports they are the Cheere , and Vrine .
# Generated sentence 2
#  O , or else That did ? 1 .
# Generated sentence 3
#  2 .
# Generated sentence 4
#  Adde thereto a most diminitiue of helpe : Behold , Vnder a blessed time .
# Generated sentence 5
#  Hoboyes , his pendant Bed , What are made good caution , And yet , come , Fire burne , with their comfort with one : Macbeth Your Seruants with Feare , and for th ' d be thou thy Charme ' gainst Arme , come hither , and for all out , profound , Arme , As Honor both ' s your leysure La .
# Generated sentence 6
#  Boundlesse intemperance In deepest consequence .
# Generated sentence 7
#  Exeunt .
# Generated sentence 8
#  It will not be counsail ' th ' d Euents , come .
# Generated sentence 9
#  Exeunt .
# Generating sentences from book shakespeare-macbeth.txt using trigrams
# Generated sentence 0
#  But ' tis hee : The greatest is behinde .
# Generated sentence 1
#  So well thy words become thee , poore Monkie : But now I am fed : It is concluded : Banquo , and for Donalbane To kill their gracious Father ? Sonnes , Kinsmen , Thanes , And to be trusted with them : And went further , Lady , Rosse , Angus , Lenox , Macduff , this Noble passion Childe of integrity , hath giuen me earnest of a King , for then It hath no end We haue willing Dames enough : there the Murtherers , Steep ' d me Mother , but constrained things , Whose absence is no lesse to them , and Macbeth slaine .
# Generated sentence 2
#  Exeunt .
# Generated sentence 3
#  Exit Messenger .
# Generated sentence 4
#  And for his Issue , whose sole name blisters our tongues , That summons thee to the King ' s he feele his Title Hang loose about him , My Wife and Childrens Ghosts will haunt me still : all the Gentry ; there is Seywards Sonne , Spightfull , and each new Morne , New Widdowes howle , new Orphans cry , hold .
# Generated sentence 5
#  What concerne they , The minde I sway by , and Gulfe Of the Imperiall Theame .
# Generated sentence 6
#  We will require her welcome Padock calls anon : faire is foule , and it marres him ; Who ( as others do ) Loues for his Issue , whose armes Are hyr ' d , & midnight Hags ? I see , So they doubly redoubled stroakes vpon the order of your Charmes , The Prince of Cumberland : which Honor must Not vnaccompanied , inuest him onely , But mine owne detraction .
# Generated sentence 7
#  Rosse .
# Generated sentence 8
#  I , in our great bidding Enter Macduffes Wife , Children , Seruants , all , As the weyard Women promis ' d , while ' tis later , Sir , it prouokes , and the chance of goodnesse Be like our warranted Quarrell .
# Generated sentence 9
#  Gracious my Lord , Performe what you command vs Would they had stay ' d with that , and so I pray you ? My dearest Loue , Duncan , His Wonders and his Fleans liues Enter Malcolme , and what seem ' d Here lay Duncan , His Wonders and his Prayses doe contend , Which the Eye of pittifull Day , And say , it will make vs Med ' cine of the time .
